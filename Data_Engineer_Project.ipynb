# %%
import psycopg2
import pandas as pd

# %%
def create_database():
    
    # to make connection with database
    conn = psycopg2.connect("host=localhost user=postgres dbname=postgres password=postgres")
    conn.set_session(autocommit=True)
    
    # to create cursor for queries execution
    cur = conn.cursor()
    
    # run query
    cur.execute("DROP DATABASE IF EXISTS accounts")
    cur.execute("CREATE DATABASE accounts")
    
    # for closing current connection
    conn.close()
    
    conn = psycopg2.connect("host=localhost user=postgres dbname=accounts password=postgres")
    cur = conn.cursor()
    
    return cur, conn

# %%
#read csv file using pandas
AccountsCountry = pd.read_csv("C:\\Users\\user\\OneDrive\\Desktop\\DWH\\Wealth-AccountsCountry.csv")

# %%
#head method is used to display first five rows of given data frames
AccountsCountry.head()
# Out:
#   Country Code                  Long Name         Income Group  \
# 0          ALB        Republic of Albania  Upper middle income
# 1          ARG         Argentine Republic  Upper middle income
# 2          ARM        Republic of Armenia  Upper middle income
# 3          AUS  Commonwealth of Australia          High income
# 4          AUT        Republic of Austria          High income
#
#                      Region Lending category Other groups      Currency Unit  \
# 0      Europe  Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America  Caribbean             IBRD          NaN     Argentine peso
# 2      Europe  Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia  Pacific              NaN          NaN  Australian dollar
# 4      Europe  Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# ...

# %%
#here we can select the first 5 columns of AccountsCountry dataframe by providing columns name
#[[]] The first pair of square brackets selects the columns,
#and the second pair creates a new DataFrame with only the selected columns.

AccountsCountry_clean = AccountsCountry[["Country Code","Long Name","Income Group","Region","Lending category"]]
AccountsCountry_clean = AccountsCountry_clean.drop_duplicates(subset=['Country Code'])

# %%
AccountsCountry_clean.head()
# Out:
#   Country Code                  Long Name         Income Group  \
# 0          ALB        Republic of Albania  Upper middle income
# 1          ARG         Argentine Republic  Upper middle income
# 2          ARM        Republic of Armenia  Upper middle income
# 3          AUS  Commonwealth of Australia          High income
# 4          AUT        Republic of Austria          High income
#
#                      Region Lending category
# 0      Europe  Central Asia             IBRD
# 1  Latin America  Caribbean             IBRD
# 2      Europe  Central Asia             IBRD
# 3        East Asia  Pacific              NaN
# 4      Europe  Central Asia              NaN

# %%
#read csv file using pandas
AccountsData = pd.read_csv("C:\\Users\\user\\OneDrive\\Desktop\\DWH\\Wealth-AccountData.csv")

# %%
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
# columns method shows all the columns in given dataframe
AccountsData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
# drop method is used to delete the given columns from dataframe
AccountsData = AccountsData.drop(['1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
       '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
       '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
       '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
       '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],axis=1)

# %%
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998]
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10
# 1      14072.79      13708.99       11794.1      12399.48
# 2      3468.858      3355.549      2868.997      3013.391
# 3      6507.931      6353.737      5466.692      5901.072
# 4      4893.006      4737.857      4059.321      4191.445

# %%
AccountsSeries = pd.read_csv("C:\\Users\\user\\OneDrive\\Desktop\\DWH\\Wealth-AccountSeries.csv")

# %%
AccountsSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
AccountsSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
AccountsSeries = AccountsSeries[['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic']]

# %%
AccountsSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
# calling our function
cur, conn = create_database()
# Out:
# ---------------------------------------------------------------------------
# ObjectInUse                               Traceback (most recent call last)
# <ipython-input-64-fe350d481811> in <module>
# ----> 1 cur, conn = create_database()
#
# <ipython-input-47-f98baef0268b> in create_database()
#       9
#      10     # run query
# ---> 11     cur.execute("DROP DATABASE IF EXISTS accounts")
#      12     cur.execute("CREATE DATABASE accounts")
#      13
#
# ObjectInUse: database "accounts" is being accessed by other users
# DETAIL:  There are 2 other sessions using the database.

# %%
# store the multilines string query in variable 
accountscountry_table_create = ("""CREATE TABLE IF NOT EXISTS accountscountry(Country_Code VARCHAR PRIMARY KEY,
Long_Name VARCHAR,
Income_Group VARCHAR,
Region VARCHAR,
Lending_category VARCHAR)""")
# run the query
cur.execute(accountscountry_table_create)
conn.commit()

# %%
accountsdata_table_create = ("""CREATE TABLE IF NOT EXISTS accountsdata(
country_name VARCHAR,
country_code VARCHAR,
series_name VARCHAR,
series_code VARCHAR,
YR1995 VARCHAR,
YR1996 VARCHAR,
YR1997 VARCHAR,
YR1998 VARCHAR)""")

cur.execute(accountsdata_table_create)
conn.commit()

# %%
accountsseries_table_create = ("""CREATE TABLE IF NOT EXISTS accountsseries(
Code VARCHAR,
Indicator_Name VARCHAR,
Long_definition VARCHAR,
Source VARCHAR,
Topic VARCHAR)""")

cur.execute(accountsseries_table_create)
conn.commit()

# %%
accountscountry_table_insert = ("""INSERT INTO accountscountry(
Country_Code,
Long_Name,
Income_Group,
Region,
Lending_category)
VALUES(%s,%s,%s,%s,%s)""")

# %%
# iterrows allows you to iterate over the rows of a DataFrame as a sequence of (index, Series) pairs
for i, row in AccountsCountry_clean.iterrows():
    cur.execute(accountscountry_table_insert,list(row))
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# <ipython-input-103-46a5a76dc85f> in <module>
#       1 # iterrows allows you to iterate over the rows of a DataFrame as a sequence of (index, Series) pairs
#       2 for i, row in AccountsCountry_clean.iterrows():
# ----> 3     cur.execute(accountscountry_table_insert,list(row))
#
# UniqueViolation: duplicate key value violates unique constraint "accountscountry_pkey"
# DETAIL:  Key (country_code)=(ALB) already exists.

# %%
conn.commit()

# %%
accountsdata_table_insert = ("""INSERT INTO accountsdata(
country_name,
country_code,
series_name,
series_code,
YR1995,
YR1996,
YR1997,
YR1998)
VALUES(%s,%s,%s,%s,%s,%s,%s,%s)""")

# %%
for i, row in AccountsData.iterrows():
    cur.execute(accountsdata_table_insert,list(row))
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# <ipython-input-120-007cee7c954b> in <module>
#       1 for i, row in AccountsData.iterrows():
# ----> 2     cur.execute(accountsdata_table_insert,list(row))
#
# InvalidTextRepresentation: invalid input syntax for type integer: "4.49E+10"
# LINE 10: ...','Human capital (constant 2018 US$)','NW.HCA.TO','4.49E+10'...
#                                                               ^

# %%
accountsseries_table_insert = ("""INSERT INTO accountsseries(
Code,
Indicator_Name,
Long_definition,
Source,
Topic)
VALUES(%s,%s,%s,%s,%s)""")

# %%
for i, row in AccountsSeries.iterrows():
    cur.execute(accountsseries_table_insert,list(row))

# %%
conn.commit()
